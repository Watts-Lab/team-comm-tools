# %%
import pandas as pd
df = pd.read_csv('feature_engine/output/chat/test_named_entity_chat_level.csv')

# %%
df[['message', 'num_named_entity', 'named_entities']]
# Out:
#                                                message  num_named_entity  \
# 0          hey joanna have you finished the assignment                 1
# 1                  yes i completed it yesterday jaidyn                 1
# 2          louis do you have any plans for the weekend                 1
# 3             not really kate just hanging out at home                 1
# 4               michael have you heard the latest news                 1
# ..                                                 ...               ...
# 105             nikki did you see thomas the other day                 2
# 106                    no i didnt nick but tom did you                 2
# 107        i think alex and adam and eve went canoeing                 3
# 108  roger and ashley and sasha and kayla are all l...                 3
# 109  do you want to go fishing with eugene and william                 2
#
#                                         named_entities
# ...
